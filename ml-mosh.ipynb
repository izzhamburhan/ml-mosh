# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib
from sklearn import tree

## -- music_data collect data from csv file(preparing data)
music_data = pd.read_csv('music.csv')
x = music_data.drop(columns=['genre'])
y = music_data['genre']

## -- for check accuracy
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

## -- machine learning(learning & predicting)
model = DecisionTreeClassifier()
# model.fit(x_train, y_train) - to check accuracy
model.fit(x,y)
predictions = model.predict(x_test)

score = accuracy_score(y_test, predictions)
score
# Out:
# 1.0

# %%
# model_1 = DecisionTreeClassifier()
# model_1.fit(x, y)

joblib.dump(model_1, 'music-recommender.joblib')
predictions_1 = model_1.predict([ [21, 1] ])
predictions_1
# Out:
# array(['HipHop'], dtype=object)

# %%
tree.export_graphviz(model, out_file='music-recommender.dot', 
                     feature_names=['age', 'gender'], 
                     class_names=sorted(y.unique()),
                    label='all',
                    rounded=True,
                    filled=True)
